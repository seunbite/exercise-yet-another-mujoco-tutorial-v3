# %% [markdown]
# ### Inverse Kinematics
# ```
# Inverse kinematics finds the corresponding joint positions given target end-effector poses.
# ```
# - Inverse kinematics (IK) can be solved in two different ways: analytic and numerical
# - In this tutorial, we focus on the numerical way of solving IK using a Jacobian matrix

# %%
import mujoco,sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.append('../package/helper/')
sys.path.append('../package/mujoco_usage/')
from mujoco_parser import *
from transformation import *
from slider import *
from utility import *
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
print ("MuJoCo:[%s]"%(mujoco.__version__))
# Out:
# MuJoCo:[3.1.1]

# %% [markdown]
# #### Parse `UR5e`

# %%
xml_path = '../asset/tabletop_manipulation/scene_ur5e_cylinders.xml'
env = MuJoCoParserClass(name='Tabletop',rel_xml_path=xml_path,verbose=True)
# Out:
# name:[Tabletop] dt:[0.002] HZ:[500]
# n_qpos:[68] n_qvel:[60] n_qacc:[60] n_ctrl:[7]
#
# n_body:[29]
#  [0/29] [world] mass:[0.00]kg
#  [1/29] [front_object_table] mass:[1.00]kg
#  [2/29] [side_object_table] mass:[1.00]kg
#  [3/29] [ur_base] mass:[4.00]kg
#  [4/29] [ur_shoulder_link] mass:[3.70]kg
#  [5/29] [ur_upper_arm_link] mass:[8.39]kg
#  [6/29] [ur_forearm_link] mass:[2.27]kg
#  [7/29] [ur_wrist_1_link] mass:[1.22]kg
#  [8/29] [ur_wrist_2_link] mass:[1.22]kg
#  [9/29] [ur_wrist_3_link] mass:[0.19]kg
#  [10/29] [ur_tcp_link] mass:[0.00]kg
#  [11/29] [ur_camera_mount] mass:[0.09]kg
#  [12/29] [ur_d435i] mass:[0.07]kg
#  [13/29] [ur_rg2_gripper_base_link] mass:[0.20]kg
#  [14/29] [ur_camera_center] mass:[0.00]kg
#  [15/29] [ur_rg2_gripper_finger1_finger_link] mass:[0.01]kg
#  [16/29] [ur_rg2_gripper_finger1_inner_knuckle_link] mass:[0.01]kg
#  [17/29] [ur_rg2_gripper_finger1_finger_tip_link] mass:[0.01]kg
#  [18/29] [ur_rg2_gripper_finger2_finger_link] mass:[0.01]kg
#  [19/29] [ur_rg2_gripper_finger2_inner_knuckle_link] mass:[0.01]kg
#  [20/29] [ur_rg2_gripper_finger2_finger_tip_link] mass:[0.01]kg
#  [21/29] [obj_cylinder_01] mass:[0.20]kg
#  [22/29] [obj_cylinder_02] mass:[0.20]kg
#  [23/29] [obj_cylinder_03] mass:[0.20]kg
#  [24/29] [obj_cylinder_04] mass:[0.20]kg
#  [25/29] [obj_cylinder_05] mass:[0.20]kg
#  [26/29] [obj_cylinder_06] mass:[0.20]kg
#  [27/29] [obj_cylinder_07] mass:[0.20]kg
#  [28/29] [obj_cylinder_08] mass:[0.20]kg
# body_total_mass:[24.99]kg
#
# n_geom:[60]
# geom_names:['floor', 'front_object_table', 'side_object_table', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'rg2_gripper_finger1_finger_tip_geom', None, None, 'rg2_gripper_finger2_finger_tip_geom', None, None, None, None, None, None, None, None]
#
# n_joint:[20]
#  [0/20] [shoulder_pan_joint] axis:[0. 0. 1.]
#  [1/20] [shoulder_lift_joint] axis:[0. 1. 0.]
#  [2/20] [elbow_joint] axis:[0. 1. 0.]
#  [3/20] [wrist_1_joint] axis:[0. 1. 0.]
#  [4/20] [wrist_2_joint] axis:[0. 0. 1.]
#  [5/20] [wrist_3_joint] axis:[0. 1. 0.]
#  [6/20] [gripper_finger1_joint] axis:[0. 1. 0.]
#  [7/20] [gripper_finger1_inner_knuckle_joint] axis:[0. 1. 0.]
#  [8/20] [gripper_finger1_finger_tip_joint] axis:[0. 1. 0.]
#  [9/20] [gripper_finger2_joint] axis:[0. 1. 0.]
#  [10/20] [gripper_finger2_inner_knuckle_joint] axis:[0. 1. 0.]
#  [11/20] [gripper_finger2_finger_tip_joint] axis:[0. 1. 0.]
#  [12/20] [None] axis:[0. 0. 1.]
#  [13/20] [None] axis:[0. 0. 1.]
#  [14/20] [None] axis:[0. 0. 1.]
#  [15/20] [None] axis:[0. 0. 1.]
#  [16/20] [None] axis:[0. 0. 1.]
#  [17/20] [None] axis:[0. 0. 1.]
#  [18/20] [None] axis:[0. 0. 1.]
#  [19/20] [None] axis:[0. 0. 1.]
#
# n_dof:[60] (=number of rows of Jacobian)
#  [0/60] [None] attached joint:[shoulder_pan_joint] body:[ur_shoulder_link]
#  [1/60] [None] attached joint:[shoulder_lift_joint] body:[ur_upper_arm_link]
#  [2/60] [None] attached joint:[elbow_joint] body:[ur_forearm_link]
#  [3/60] [None] attached joint:[wrist_1_joint] body:[ur_wrist_1_link]
#  [4/60] [None] attached joint:[wrist_2_joint] body:[ur_wrist_2_link]
#  [5/60] [None] attached joint:[wrist_3_joint] body:[ur_wrist_3_link]
#  [6/60] [None] attached joint:[gripper_finger1_joint] body:[ur_rg2_gripper_finger1_finger_link]
#  [7/60] [None] attached joint:[gripper_finger1_inner_knuckle_joint] body:[ur_rg2_gripper_finger1_inner_knuckle_link]
#  [8/60] [None] attached joint:[gripper_finger1_finger_tip_joint] body:[ur_rg2_gripper_finger1_finger_tip_link]
#  [9/60] [None] attached joint:[gripper_finger2_joint] body:[ur_rg2_gripper_finger2_finger_link]
#  [10/60] [None] attached joint:[gripper_finger2_inner_knuckle_joint] body:[ur_rg2_gripper_finger2_inner_knuckle_link]
#  [11/60] [None] attached joint:[gripper_finger2_finger_tip_joint] body:[ur_rg2_gripper_finger2_finger_tip_link]
#  [12/60] [None] attached joint:[None] body:[obj_cylinder_01]
#  [13/60] [None] attached joint:[None] body:[obj_cylinder_01]
#  [14/60] [None] attached joint:[None] body:[obj_cylinder_01]
#  [15/60] [None] attached joint:[None] body:[obj_cylinder_01]
#  [16/60] [None] attached joint:[None] body:[obj_cylinder_01]
#  [17/60] [None] attached joint:[None] body:[obj_cylinder_01]
#  [18/60] [None] attached joint:[None] body:[obj_cylinder_02]
#  [19/60] [None] attached joint:[None] body:[obj_cylinder_02]
#  [20/60] [None] attached joint:[None] body:[obj_cylinder_02]
#  [21/60] [None] attached joint:[None] body:[obj_cylinder_02]
#  [22/60] [None] attached joint:[None] body:[obj_cylinder_02]
#  [23/60] [None] attached joint:[None] body:[obj_cylinder_02]
#  [24/60] [None] attached joint:[None] body:[obj_cylinder_03]
#  [25/60] [None] attached joint:[None] body:[obj_cylinder_03]
#  [26/60] [None] attached joint:[None] body:[obj_cylinder_03]
#  [27/60] [None] attached joint:[None] body:[obj_cylinder_03]
#  [28/60] [None] attached joint:[None] body:[obj_cylinder_03]
#  [29/60] [None] attached joint:[None] body:[obj_cylinder_03]
#  [30/60] [None] attached joint:[None] body:[obj_cylinder_04]
#  [31/60] [None] attached joint:[None] body:[obj_cylinder_04]
#  [32/60] [None] attached joint:[None] body:[obj_cylinder_04]
#  [33/60] [None] attached joint:[None] body:[obj_cylinder_04]
#  [34/60] [None] attached joint:[None] body:[obj_cylinder_04]
#  [35/60] [None] attached joint:[None] body:[obj_cylinder_04]
#  [36/60] [None] attached joint:[None] body:[obj_cylinder_05]
#  [37/60] [None] attached joint:[None] body:[obj_cylinder_05]
#  [38/60] [None] attached joint:[None] body:[obj_cylinder_05]
#  [39/60] [None] attached joint:[None] body:[obj_cylinder_05]
#  [40/60] [None] attached joint:[None] body:[obj_cylinder_05]
#  [41/60] [None] attached joint:[None] body:[obj_cylinder_05]
#  [42/60] [None] attached joint:[None] body:[obj_cylinder_06]
#  [43/60] [None] attached joint:[None] body:[obj_cylinder_06]
#  [44/60] [None] attached joint:[None] body:[obj_cylinder_06]
#  [45/60] [None] attached joint:[None] body:[obj_cylinder_06]
#  [46/60] [None] attached joint:[None] body:[obj_cylinder_06]
#  [47/60] [None] attached joint:[None] body:[obj_cylinder_06]
#  [48/60] [None] attached joint:[None] body:[obj_cylinder_07]
#  [49/60] [None] attached joint:[None] body:[obj_cylinder_07]
#  [50/60] [None] attached joint:[None] body:[obj_cylinder_07]
#  [51/60] [None] attached joint:[None] body:[obj_cylinder_07]
#  [52/60] [None] attached joint:[None] body:[obj_cylinder_07]
#  [53/60] [None] attached joint:[None] body:[obj_cylinder_07]
#  [54/60] [None] attached joint:[None] body:[obj_cylinder_08]
#  [55/60] [None] attached joint:[None] body:[obj_cylinder_08]
#  [56/60] [None] attached joint:[None] body:[obj_cylinder_08]
#  [57/60] [None] attached joint:[None] body:[obj_cylinder_08]
#  [58/60] [None] attached joint:[None] body:[obj_cylinder_08]
#  [59/60] [None] attached joint:[None] body:[obj_cylinder_08]
#
# Free joint information. n_free_joint:[8]
#  [0/8] [None] body_name_attached:[obj_cylinder_01]
#  [1/8] [None] body_name_attached:[obj_cylinder_02]
#  [2/8] [None] body_name_attached:[obj_cylinder_03]
#  [3/8] [None] body_name_attached:[obj_cylinder_04]
#  [4/8] [None] body_name_attached:[obj_cylinder_05]
#  [5/8] [None] body_name_attached:[obj_cylinder_06]
#  [6/8] [None] body_name_attached:[obj_cylinder_07]
#  [7/8] [None] body_name_attached:[obj_cylinder_08]
#
# Revolute joint information. n_rev_joint:[12]
#  [0/12] [shoulder_pan_joint] range:[-6.283]~[6.283]
#  [1/12] [shoulder_lift_joint] range:[-6.283]~[6.283]
#  [2/12] [elbow_joint] range:[-3.142]~[3.142]
#  [3/12] [wrist_1_joint] range:[-6.283]~[6.283]
#  [4/12] [wrist_2_joint] range:[-6.283]~[6.283]
#  [5/12] [wrist_3_joint] range:[-6.283]~[6.283]
#  [6/12] [gripper_finger1_joint] range:[-1.500]~[0.000]
#  [7/12] [gripper_finger1_inner_knuckle_joint] range:[-1.500]~[0.000]
#  [8/12] [gripper_finger1_finger_tip_joint] range:[-2.500]~[2.500]
#  [9/12] [gripper_finger2_joint] range:[0.000]~[1.500]
#  [10/12] [gripper_finger2_inner_knuckle_joint] range:[0.000]~[1.500]
#  [11/12] [gripper_finger2_finger_tip_joint] range:[-2.500]~[2.500]
#
# Prismatic joint information. n_pri_joint:[0]
#
# Control information. n_ctrl:[7]
#  [0/7] [shoulder_pan] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [1/7] [shoulder_lift] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [2/7] [elbow] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [3/7] [wrist_1] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [4/7] [wrist_2] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [5/7] [wrist_3] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [6/7] [gripper] range:[0.000]~[2.000] gear:[1.00] type:[JOINT]
#
# n_sensor:[0]
# sensor_names:[]
# n_site:[1]
# site_names:['attachment_site']

# %% [markdown]
# #### To solve IK
# - compute the Jacobian matrix of the target body using `mujoco.mj_jacBody`
# - compute the position and rotation error
# - compute dq using least squares
# - update

# %% [markdown]
# #### Dynamic Simulation using slider control with solving IK

# %%
sliders = MultiSliderClass( # Slider for EE control
    n_slider      = 7,
    title         = 'Sliders for [%s] Control'%(env.name),
    window_width  = 450,
    window_height = 300,
    x_offset      = 0,
    y_offset      = 100,
    slider_width  = 300,
    label_texts   = ['X','Y','Z','Roll-deg','Pitch-deg','Yaw-deg','Gripper'],
    slider_mins   = [-1,-1,-1,-180,-180,-180,0],
    slider_maxs   = [+1,+1,+1,+180,+180,+180,2],
    slider_vals   = [0,0,0,0,0,0,0],
    resolutions   = [0.02,0.02,0.02,3.6,3.6,3.6,0.04], # range/50
    verbose       = False,
)
joint_names = ['shoulder_pan_joint','shoulder_lift_joint','elbow_joint',
               'wrist_1_joint','wrist_2_joint','wrist_3_joint']
q0 = np.deg2rad([-35.63,-78.2,153.42,-75.22,54.37,-0.])
p0 = env.get_p_body(body_name='ur_base')+np.array([0.5,0.0,0.05])
R0 = rpy_deg2r([-180,0,90])
env.init_viewer(
    title       = 'Tabletop',
    transparent = False,
    azimuth     = 133,
    distance    = 3.5,
    elevation   = -42.4,
    lookat      = (-0.06,0.07,0.31),
)
env.reset() # reset
env.forward(q=q0,joint_names=joint_names) # initial position

# Move object positions
obj_names = env.get_body_names(prefix='obj_')
n_obj = len(obj_names)
obj_xyzs = sample_xyzs(
    n_sample  = n_obj,
    x_range   = [+0.6,+1.0],
    y_range   = [-0.45,+0.45],
    z_range   = [0.8,0.81],
    min_dist  = 0.2,
    xy_margin = 0.0
)
for obj_idx in range(n_obj):
    env.set_p_base_body(body_name=obj_names[obj_idx],p=obj_xyzs[obj_idx,:])
    env.set_R_base_body(body_name=obj_names[obj_idx],R=np.eye(3,3))
env.set_geom_color(body_names_to_color=obj_names,rgba_list=get_colors(n_obj))
    
# Loop
q_ik_init = q0.copy()
while env.is_viewer_alive():
    
    # Update
    sliders.update() # update slider
    xyzrpyg = sliders.get_slider_values()
    qpos,ik_err_stack,ik_info = solve_ik(
        env                = env,
        joint_names_for_ik = joint_names,
        body_name_trgt     = 'ur_tcp_link',
        q_init             = q_ik_init,
        p_trgt             = xyzrpyg[:3]+p0,
        R_trgt             = rpy_deg2r(xyzrpyg[3:6])@R0,
        max_ik_tick        = 500,
        ik_stepsize        = 1.0,
        ik_eps             = 1e-2,
        ik_th              = np.radians(5.0),
        render             = False,
        verbose_warning    = False,
    )
    ik_err = np.abs(ik_err_stack).max() # IK error
    if ik_err < 1e-2: q_ik_init = qpos.copy()
    else: q_ik_init = q0.copy()
    env.step( # dynamic update
        ctrl        = np.append(qpos,xyzrpyg[6]),
        joint_names = joint_names+['gripper_finger2_joint'])

    # Click handler
    xyz_click,flag_click = env.get_xyz_left_double_click()
    if flag_click: print ("[CLICKED] p:%s"%(xyz_click))
    
    # Render 
    if env.loop_every(tick_every=10):
        env.plot_T(
            T=env.get_T_body(body_name='ur_base'),
            axis_len=0.5,print_xyz=False)
        env.plot_text(
            p=env.get_p_body(body_name='ur_base')+np.array([0,0,0.5]),
            label = 'time:[%.2f]sec ik_err:[%.3f]'%(env.get_sim_time(),ik_err))
        env.plot_body_T(body_name='ur_tcp_link',axis_len=0.1,axis_width=0.005)
        env.plot_contact_info(
            r_arrow=0.005,h_arrow=0.1,rgba_contact=(1,0,0,0.5),plot_sphere=False)
        plot_ik_info(env=env,ik_info=ik_info)
        if xyz_click is not None:
            env.plot_sphere(p=xyz_click,r=0.01,rgba=(1,0,0,0.5))
        env.render()
    if env.loop_every(tick_every=5000): 
        img = env.grab_image()
        plt.figure(figsize=(6,4)); plt.imshow(img); 
        plt.title('tick:[%d] time:[%.2f]sec'%
                  (env.tick,env.get_sim_time()),fontsize=9)
        plt.axis('off'); plt.show()

# Close
env.close_viewer()
sliders.close()
print ("Done.")
# Out:
# Done.

# %% [markdown]
# #### Kinematic Simulation using slider control with solving IK

# %%
sliders = MultiSliderClass( # Slider for EE control
    n_slider      = 7,
    title         = 'Sliders for [%s] Control'%(env.name),
    window_width  = 450,
    window_height = 300,
    x_offset      = 0,
    y_offset      = 100,
    slider_width  = 300,
    label_texts   = ['X','Y','Z','Roll-deg','Pitch-deg','Yaw-deg','Gripper'],
    slider_mins   = [-1,-1,-1,-180,-180,-180,0],
    slider_maxs   = [+1,+1,+1,+180,+180,+180,2],
    slider_vals   = [0,0,0,0,0,0,0],
    resolutions   = [0.02,0.02,0.02,3.6,3.6,3.6,0.04], # range/50
    verbose       = False,
)
joint_names = ['shoulder_pan_joint','shoulder_lift_joint','elbow_joint',
               'wrist_1_joint','wrist_2_joint','wrist_3_joint']
q0 = np.deg2rad([-35.63,-78.2,153.42,-75.22,54.37,-0.])
p0 = env.get_p_body(body_name='ur_base')+np.array([0.5,0.0,0.05])
R0 = rpy_deg2r([-180,0,90])
env.init_viewer(
    title       = 'Tabletop',
    transparent = False,
    azimuth     = 133,
    distance    = 3.5,
    elevation   = -42.4,
    lookat      = (-0.06,0.07,0.31),
)
env.reset() # reset
env.forward(q=q0,joint_names=joint_names) # initial position

# Move object positions
obj_names = env.get_body_names(prefix='obj_')
n_obj = len(obj_names)
obj_xyzs = sample_xyzs(
    n_sample  = n_obj,
    x_range   = [+0.6,+1.0],
    y_range   = [-0.45,+0.45],
    z_range   = [0.8,0.81],
    min_dist  = 0.2,
    xy_margin = 0.0
)
for obj_idx in range(n_obj):
    env.set_p_base_body(body_name=obj_names[obj_idx],p=obj_xyzs[obj_idx,:])
    env.set_R_base_body(body_name=obj_names[obj_idx],R=np.eye(3,3))
env.set_geom_color(body_names_to_color=obj_names,rgba_list=get_colors(n_obj))
    
# Loop
q_ik_init = q0.copy()
while env.is_viewer_alive():
    
    # Update
    sliders.update() # update slider
    xyzrpyg = sliders.get_slider_values()
    qpos,ik_err_stack,ik_info = solve_ik(
        env                = env,
        joint_names_for_ik = joint_names,
        body_name_trgt     = 'ur_tcp_link',
        q_init             = q_ik_init,
        p_trgt             = xyzrpyg[:3]+p0,
        R_trgt             = rpy_deg2r(xyzrpyg[3:6])@R0,
        max_ik_tick        = 500,
        ik_stepsize        = 1.0,
        ik_eps             = 1e-2,
        ik_th              = np.radians(5.0),
        render             = False,
        verbose_warning    = False,
    )
    ik_err = np.abs(ik_err_stack).max() # IK error
    if ik_err < 1e-2: q_ik_init = qpos.copy()
    else: q_ik_init = q0.copy()    
    env.forward(q=qpos,joint_names=joint_names) # kinematic update

    # Click handler
    xyz_click,flag_click = env.get_xyz_left_double_click()
    if flag_click: print ("[CLICKED] p:%s"%(xyz_click))
    
    # Render 
    if env.loop_every(tick_every=10):
        env.plot_T(
            T=env.get_T_body(body_name='ur_base'),
            axis_len=0.5,print_xyz=False)
        env.plot_text(
            p=env.get_p_body(body_name='ur_base')+np.array([0,0,0.5]),
            label = 'time:[%.2f]sec ik_err:[%.3f]'%(env.get_sim_time(),ik_err))
        env.plot_body_T(body_name='ur_tcp_link',axis_len=0.1,axis_width=0.005)
        env.plot_contact_info(
            r_arrow=0.005,h_arrow=0.1,rgba_contact=(1,0,0,0.5),plot_sphere=False)
        plot_ik_info(env=env,ik_info=ik_info)
        if xyz_click is not None:
            env.plot_sphere(p=xyz_click,r=0.01,rgba=(1,0,0,0.5))
        env.render()
    if env.loop_every(tick_every=5000): 
        img = env.grab_image()
        plt.figure(figsize=(6,4)); plt.imshow(img); 
        plt.title('tick:[%d] time:[%.2f]sec'%
                  (env.tick,env.get_sim_time()),fontsize=9)
        plt.axis('off'); plt.show()

# Close
env.close_viewer()
sliders.close()
print ("Done.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 55
#      53 sliders.update() # update slider
#      54 xyzrpyg = sliders.get_slider_values()
# ---> 55 qpos,ik_err_stack,ik_info = solve_ik(
#      56     env                = env,
#      57     joint_names_for_ik = joint_names,
#      58     body_name_trgt     = 'ur_tcp_link',
#      59     q_init             = q_ik_init,
#      60     p_trgt             = xyzrpyg[:3]+p0,
#      61     R_trgt             = rpy_deg2r(xyzrpyg[3:6])@R0,
#      62     max_ik_tick        = 500,
#      63     ik_stepsize        = 1.0,
#      64     ik_eps             = 1e-2,
#      65     ik_th              = np.radians(5.0),
#      66     render             = False,
#      67     verbose_warning    = False,
#      68 )
#      69 ik_err = np.abs(ik_err_stack).max() # IK error
#      70 if ik_err < 1e-2: q_ik_init = qpos.copy()
#
# File ~/Downloads/workspace/yet-another-mujoco-tutorial-v3/notebook/../package/mujoco_usage/mujoco_parser.py:2161, in solve_ik(env, joint_names_for_ik, body_name_trgt, q_init, p_trgt, R_trgt, max_ik_tick, ik_err_th, restore_state, ik_stepsize, ik_eps, ik_th, verbose, verbose_warning, reset_env, render, render_every)
#    2159 q_curr = env.get_qpos_joints(joint_names=joint_names_for_ik)
#    2160 for ik_tick in range(max_ik_tick):
# -> 2161     dq,ik_err_stack = get_dq_from_ik_info(
#    2162         env            = env,
#    2163         ik_info        = ik_info,
#    2164         stepsize       = ik_stepsize,
#    2165         eps            = ik_eps,
#    2166         th             = ik_th,
#    2167         joint_idxs_jac = joint_idxs_jac,
#    2168     )
#    2169     q_curr = q_curr + dq[joint_idxs_jac] # update
#    2170     q_curr = np.clip(q_curr,q_mins,q_maxs) # clip
#
# File ~/Downloads/workspace/yet-another-mujoco-tutorial-v3/notebook/../package/mujoco_usage/mujoco_parser.py:2048, in get_dq_from_ik_info(env, ik_info, stepsize, eps, th, joint_idxs_jac)
#    2045     J_stack[:,joint_idxs_jac] = J_stack_backup[:,joint_idxs_jac]
#    2047 # Compute dq from damped least square
# -> 2048 dq = env.damped_ls(J_stack,ik_err_stack,stepsize=stepsize,eps=eps,th=th)
#    2049 return dq,ik_err_stack
#
# File ~/Downloads/workspace/yet-another-mujoco-tutorial-v3/notebook/../package/mujoco_usage/mujoco_parser.py:1701, in MuJoCoParserClass.damped_ls(self, J, err, eps, stepsize, th)
#    1697 def damped_ls(self,J,err,eps=1e-6,stepsize=1.0,th=5*np.pi/180.0):
#    1698     """
#    1699         Dampled least square for IK
#    1700     """
# -> 1701     dq = stepsize*np.linalg.solve(a=(J.T@J)+eps*np.eye(J.shape[1]),b=J.T@err)
#    1702     dq = trim_scale(x=dq,th=th)
#    1703     return dq
#
# File <__array_function__ internals>:200, in solve(*args, **kwargs)
#
# File ~/miniconda3/envs/3.11/lib/python3.11/site-packages/numpy/linalg/linalg.py:386, in solve(a, b)
#     384 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     385 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 386 r = gufunc(a, b, signature=signature, extobj=extobj)
#     388 return wrap(r.astype(result_t, copy=False))
#
# KeyboardInterrupt:
